# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
RF_Vpp = [40, 50, 60, 80, 100, 90]
amp = [16.1, 22.9, 35.0, 45.4, 42.7, 45.2]

# %%
plt.plot(RF_Vpp, amp, ".")
plt.xlabel("RF $V_{\mathrm{p-p}}$ [V]")
plt.ylabel("amplitude [a.u.]")
plt.grid()
